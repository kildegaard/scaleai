# %%
import pandas as pd

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Read the CSV file into a DataFrame
df = pd.read_csv("Premium Collection Audit - Sheet1.csv", sep=";")

# Display the first 5 rows
print(df.head().to_markdown(index=False, numalign="left", stralign="left"))

# Print the column names and their data types
print(df.info())

import altair as alt

# Filter out rows with null values in any of the columns.
filtered_df = df.dropna()

# Calculate and print descriptive statistics of `Total Premium`
print("The descriptive statistics of the Total Premium are as follows:")
print(
    filtered_df["Total Premium"]
    .describe()
    .to_markdown(numalign="left", stralign="left")
)

# Plot a histogram of `Total Premium`

chart = (
    alt.Chart(filtered_df)
    .mark_bar()
    .encode(
        alt.X("Total Premium:Q", bin=True, title="Total Premium"),
        alt.Y("count()", title="Count of Policies"),
        tooltip=[alt.Tooltip("Total Premium:Q", bin=True), "count()"],
    )
    .properties(title="Distribution of Total Premium")
)

chart.save("total_premium_histogram.json")

import json

# Cargar el gráfico desde el archivo JSON
with open("total_premium_histogram.json", "r") as f:
    chart_json = json.load(f)
# Mostrar el gráfico utilizando Altair
altair_chart = alt.Chart.from_dict(chart_json)
altair_chart
# Out:
# | Audit ID    | Policy ID Number   | Days of Delinquent Payment   | Auto Policy   | Homeowners Policy   | Total Premium   | Number of Delinquencies (Past 12 Months)   |
# |:------------|:-------------------|:-----------------------------|:--------------|:--------------------|:----------------|:-------------------------------------------|
# | AUD13928103 | 4,8194E+11         | 8                            | VERDADERO     | FALSO               | $125,39         | 1                                          |
# | AUD13928104 | 4,8194E+11         | 10                           | VERDADERO     | FALSO               | $291,43         | 0                                          |
# | AUD13928105 | 4,8194E+11         | 8                            | VERDADERO     | FALSO               | $92,51          | 0                                          |
# | AUD13928106 | 4,8194E+11         | 8                            | FALSO         | VERDADERO           | $724,43         | 0                                          |
# | AUD13928107 | 4,8194E+11         | 9                            | VERDADERO     | FALSO               | $117,92         | 1                                          |
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Audit ID                                  53 non-null     object
#  1   Policy ID Number                          53 non-null     object
#  2   Days of Delinquent Payment                53 non-null     float64
#  3   Auto Policy                               53 non-null     object
#  4   Homeowners Policy                         53 non-null     object
#  5   Total Premium                             53 non-null     object
#  6   Number of Delinquencies (Past 12 Months)  53 non-null     float64
# dtypes: float64(2), object(5)
# memory usage: 54.8+ KB
# None
# The descriptive statistics of the Total Premium are as follows:
# |        | Total Premium   |
# |:-------|:----------------|
# | count  | 53              |
# | unique | 53              |
# | top    | $125,39         |
# | freq   | 1               |
# alt.Chart(...)

# %%
import pandas as pd
import altair as alt
import json

# Set display options for Pandas
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Read the CSV file into a DataFrame
df = pd.read_csv("Premium Collection Audit - Sheet1.csv", sep=";")

# Display the first 5 rows
print(df.head())

# Print the column names and their data types
df.info()

# Filter out rows with null values in any of the columns
filtered_df = df

# Calculate and print descriptive statistics of `Total Premium`
print("The descriptive statistics of the Total Premium are as follows:")
print(filtered_df["Total Premium"].describe())

# Plot a histogram of `Total Premium`
chart = (
    alt.Chart(filtered_df)
    .mark_bar(size=20)
    .encode(
        x=alt.X("Total Premium:Q", bin=True, title="Total Premium"),
        y=alt.Y("count()", title="Count of Policies"),
        tooltip=[alt.Tooltip("Total Premium:Q", bin=True), "count()"],
    )
    .properties(title="Distribution of Total Premium")
    .interactive()
)

# Save the chart to a JSON file
chart.save("total_premium_histogram.json")

# Load the chart from the JSON file
with open("total_premium_histogram.json", "r") as f:
    chart_json = json.load(f)

# Display the chart using Altair
altair_chart = alt.Chart.from_dict(chart_json)
altair_chart.display()
# Out:
#       Audit ID Policy ID Number  Days of Delinquent Payment Auto Policy  \
# 0  AUD13928103       4,8194E+11                         8.0   VERDADERO
# 1  AUD13928104       4,8194E+11                        10.0   VERDADERO
# 2  AUD13928105       4,8194E+11                         8.0   VERDADERO
# 3  AUD13928106       4,8194E+11                         8.0       FALSO
# 4  AUD13928107       4,8194E+11                         9.0   VERDADERO
#
#   Homeowners Policy Total Premium  Number of Delinquencies (Past 12 Months)
# 0             FALSO       $125,39                                       1.0
# 1             FALSO       $291,43                                       0.0
# 2             FALSO        $92,51                                       0.0
# 3         VERDADERO       $724,43                                       0.0
# 4             FALSO       $117,92                                       1.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Audit ID                                  53 non-null     object
#  1   Policy ID Number                          53 non-null     object
#  2   Days of Delinquent Payment                53 non-null     float64
#  3   Auto Policy                               53 non-null     object
#  4   Homeowners Policy                         53 non-null     object
#  5   Total Premium                             53 non-null     object
#  6   Number of Delinquencies (Past 12 Months)  53 non-null     float64
# dtypes: float64(2), object(5)
# memory usage: 54.8+ KB
# The descriptive statistics of the Total Premium are as follows:
# count          53
# unique         53
# top       $125,39
# freq            1
# Name: Total Premium, dtype: object
# alt.Chart(...)
